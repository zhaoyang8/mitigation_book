# %% [markdown]
# # Stochastic Simulation

# %% [markdown]
# ## Code variable Glossary
#
# ### Economic variables
# | Symbol | Description | Formula |
# |---|---|---|
# | $c$ | Consumption | $C_t + I_t^k +  I_t^r = \alpha K_t  \left (1 - \phi_0\left(B_t\right)^{\phi_1} \right)$ |
#
# where $B_t  \overset{\mathrm{def}}{=}   \left(1 - \frac {{\mathcal E}_t}{\beta \alpha K_t}  \right){\mathbf 1}_{\{{\mathcal E}_t  < \beta \alpha K_t\} }$.
#
# ### Social value variables
# | Symbol | Description |
# |---|---|
# | `scrd` | Social value of R&D $\frac{\left(\frac{dV}{d\hat{r}}\right)_0  {C_0}}{\delta}$ |
# | `scgw` | Social cost of global warming $\frac{-\left(\frac{dV}{dy}\right)_0 {C_0}}{\delta}$ |
#
# ### Value functions
# | Symbol | Description |
# |---|---|
# | `vt` | Value function pre–tech jump |
# | `v_post_techt` | Value function post–tech jump |
#
# ### Distortions
# | Symbol | Description |
# |---|---|
# | `ht` | Temp‑anomaly adjustment $h_y$ |
# | `hkt` | Capital adjustment $h_k$ |
# | `hjt` | Knowledge‑capital adjustment $h_r$ |
# | `gt_dmg` | Damage jump adjustment $g_\ell$ |
# | `gt_tech` | Tech jump adjustment $f_L$ |
#
# ### Probability variables
# | Symbol | Description |
# |---|---|
# | `distorted_damage_prob` | Distorted damage‑jump probability $J_\ell\,g_\ell$ |
# | `distorted_tech_prob` | Distorted tech‑jump probability $J_L\,f_L$ |
# | `true_tech_prob` | True tech‑jump probability $J_L$ |
# | `true_damage_prob` | True damage‑jump probability $J_\ell$ |
#
# ### Relative entropy terms
# | Term | Expression |
# |---|---|
# | `RelativeEntropy_hk` | $\tfrac{1}{2}\,\xi_k\,h_k^2$ |
# | `RelativeEntropy_hY` | $\tfrac{1}{2}\,\xi_c\,h_t^2$ |
# | `RelativeEntropy_hj` | $\tfrac{1}{2}\,\xi_j\,h_j^2$ |
# | `RelativeEntropy_TechJump` | $\xi_j J_L(1-f+f\log f)$ |
# | `RelativeEntropy_DamageJump` | $\xi_d \sum_\ell J_\ell(1-g_\ell+g_\ell\log g_\ell)$ |

# %% [markdown]
# ## SVRD and SCGW <a href="https://github.com/korito1416/two-capital-climate-change/blob/new_model_boundary/python/DateValueReport_Table.py" class="code-link" target="_blank" rel="noopener"></a>
#
# By definition,
#
# $$
# \begin{align*}
#     SVRD &= \frac{\left(\frac{dV}{d\hat{r}}\right)_0  \frac{C_0}{N_0}}{\delta}\\
#     SCGW &= \frac{-\left(\frac{dV}{dy}\right)_0 \frac{C_0}{N_0}}{\delta}
# \end{align*}
# $$
#
# | **Uncertainty channel**      | SVRD <br> ($\xi=0.1$)  | SVRD <br> ($\xi=0.05$)  | R&D investment / output <br> ($\xi = 0.1$) | R&D investment / output <br> ($\xi = 0.05$) |
# |-----------------------------|------------------------|------------------------|----------------------------|-----------------------------|
# | baseline ($\xi = \infty$)  | 41.1 (66%)             | 41.1 (43%)             | 0.0063                     | 0.0063                      |
# | climate uncertainty         | 42.0 (68%)             | 43.0 (45%)             | 0.0066                     | 0.0068                      |
# | damage uncertainty          | 42.4 (68%)             | 43.7 (46%)             | 0.0067                     | 0.0071                      |
# | productivity uncertainty    | 40.3 (65%)             | 39.6 (42%)             | 0.0061                     | 0.0058                      |
# | technology uncertainty      | 57.6 (93%)             | 77.5 (82%)             | 0.0123                     | 0.0223                      |
# | all channels                | 62.2                   | 95.0                   | 0.0144                     | 0.0335                      |
#
# | **Uncertainty channel**     | SCGW<br>($\xi = 0.1$)     | SCGW<br>($\xi = 0.05$)     | Emissions<br>($\xi = 0.1$) | Emissions<br>($\xi = 0.05$) |
# |----------------------------|------------------------|-------------------------|--------------------------|---------------------------|
# | baseline ($\xi = \infty$)| 54.4 (58%)             | 54.4 (29%)              | 9.32                     | 9.32                      |
# | climate uncertainty        | 55.7 (59%)             | 56.9 (30%)              | 9.30                     | 9.29                      |
# | damage uncertainty         | 56.8 (60%)             | 59.2 (32%)              | 9.29                     | 9.27                      |
# | productivity uncertainty   | 54.0 (57%)             | 53.4 (29%)              | 9.32                     | 9.32                      |
# | technology uncertainty     | 83.8 (89%)             | 133.0 (71%)             | 9.09                     | 8.79                      |
# | all channels               | 94.2                   | 186.8                   | 9.01                     | 8.47                      |
#
# <!-- ——— Reproduction instructions ——— -->
# <div style="margin:0.8rem 0 0.2rem;">
#   To reproduce Table 2 and Table 3 in the paper, run the shell scripts provided below.
# </div>
#
# ```bash
# bash ./conduction/Postdamage.sh "true" "false" "false" "false" "false"
# bash ./conduction/Postdamage_sub.sh "true" "false" "false" "false" "false"
# bash ./conduction/Predamage.sh "true" "false" "false" "false" "false"
# bash ./conduction/ZeroShockTrajectories_simulate.sh "true" "false" "false" "false"
#
# bash ./conduction/Postdamage.sh "false" "true" "false" "false" "false"
# bash ./conduction/Postdamage_sub.sh "false" "true" "false" "false" "false"
# bash ./conduction/Predamage.sh "false" "true" "false" "false" "false"
# bash ./conduction/ZeroShockTrajectories_simulate.sh "false" "true" "false" "false"
#
# bash ./conduction/Postdamage.sh "false" "false" "true" "false" "false"
# bash ./conduction/Postdamage_sub.sh "false" "false" "true" "false" "false"
# bash ./conduction/Predamage.sh "false" "false" "true" "false" "false"
# bash ./conduction/ZeroShockTrajectories_simulate.sh "false" "false" "true" "false"
#
# bash ./conduction/DateValueReport_table.sh
# ```
#
# After the run finishes, the program prints to the job-outs Graph_Table file: `MATRIX scrd` and `MATRIX scgw`. To obtain the values reported in Table 2 and Table 3, divide the columns corresponding to scrd and scgw by $N_0 = 1.0046$.
#
#
# Source scripts:
# * [**`Postdamage.sh`**](https://github.com/korito1416/two-capital-climate-change/blob/new_model_boundary/conduction/Postdamage.sh)
# * [**`Postdamage_sub.sh`**](https://github.com/korito1416/two-capital-climate-change/blob/new_model_boundary/conduction/Postdamage_sub.sh)
# * [**`Predamage.sh`**](https://github.com/korito1416/two-capital-climate-change/blob/new_model_boundary/conduction/Predamage.sh)
# * [**`ZeroShockTrajectories_simulate.sh`**](https://github.com/korito1416/two-capital-climate-change/blob/new_model_boundary/conduction/ZeroShockTrajectories_simulate.sh)
# * [**`DateValueReport_table.sh`**](https://github.com/korito1416/two-capital-climate-change/blob/new_model_boundary/conduction/DateValueReport_table.sh)

# %% [markdown]
# ## Stochastic pathways <a href="https://github.com/korito1416/two-capital-climate-change/blob/new_model_boundary/python/StocasticTrajectories_plot.py" class="code-link" target="_blank" rel="noopener"></a>
#
# Figure 7 gives four stochastic pathways for the robustly optimal choice of R&D investment and emissions. The simulations are not intended to be typical but rather are chosen to illustrate some of the possible outcomes. The pathways were generated using the baseline probabilities with the investment and emissions decision rules computed under the less averse specification.
#
# <div style="
#      display:flex;
#      gap:18px;
#      justify-content:center;
#      align-items:center;
#      flex-wrap:wrap;
# ">
#   <img src="../_static/20_damage/path_investment_RD.png"
#        alt="more aversion"
#        style="width:350px; height:auto;">
#   <img src="../_static/20_damage/path_emission.png"
#        alt="less aversion"
#        style="width:350px; height:auto;">
# </div>
#
# <iframe
#   id="plotly-div"
#   src="../_static/investment_RD_paths_Aversion Intensity_rho=1.0_delta=0.01.html"
#   width="100%"
#   height="500"
#   style="border:none;"
# ></iframe>
#
# <iframe
#   id="plotly-div"
#   src="../_static/emissions_paths_Aversion Intensity_rho=1.0_delta=0.01.html"
#   width="100%"
#   height="500"
#   style="border:none;"
# ></iframe>
#
# <!-- ——— Reproduction instructions ——— -->
# <div style="margin:0.8rem 0 0.2rem;">
#   To reproduce Figure 7 in the paper, run the shell scripts provided below.
# </div>
#
# ```bash
# bash ./conduction/Postdamage.sh "true" "false" "false" "false" "false"
# bash ./conduction/Postdamage_sub.sh "true" "false" "false" "false" "false"
# bash ./conduction/Predamage.sh "true" "false" "false" "false" "false"
# bash ./conduction/StocasticTrajectories_simulate.sh "true" "false"
# bash ./conduction/StocasticTrajectories_plot.sh "true" "false" "false"
# ```
#
# After the run finishes, you should have an output file named in a pattern similar to
# `path_investment_RD_Aversion Intensity_rho=1.0_delta=0.01.png` and
# `path_emission_Aversion Intensity_rho=1.0_delta=0.01.png`.
#
# Source scripts:
# * [**`Postdamage.sh`**](https://github.com/korito1416/two-capital-climate-change/blob/new_model_boundary/conduction/Postdamage.sh)
# * [**`Postdamage_sub.sh`**](https://github.com/korito1416/two-capital-climate-change/blob/new_model_boundary/conduction/Postdamage_sub.sh)
# * [**`Predamage.sh`**](https://github.com/korito1416/two-capital-climate-change/blob/new_model_boundary/conduction/Predamage.sh)
# * [**`StocasticTrajectories_simulate.sh`**](https://github.com/korito1416/two-capital-climate-change/blob/new_model_boundary/conduction/StocasticTrajectories_simulate.sh)
# * [**`StocasticTrajectories_plot.sh`**](https://github.com/korito1416/two-capital-climate-change/blob/new_model_boundary/conduction/StocasticTrajectories_plot.sh)

# %% [markdown]
# ## Responses to damage-curve information <a href="https://github.com/korito1416/two-capital-climate-change/blob/new_model_boundary/python/StocasticTrajectories_plot.py" class="code-link" target="_blank" rel="noopener"></a>
#
# Figure 8 gives densities for the “before and after” emissions and R&D investment responses to knowledge of any of the collection of potential damage curve realizations.
#
# <div style="
#      display:flex;
#      gap:18px;
#      justify-content:center;
#      align-items:center;
#      flex-wrap:wrap;
# ">
#   <img src="../_static/20_damage/investmentRD_damage_id1.png"
#        alt="more aversion"
#        style="width:350px; height:auto;">
#   <img src="../_static/20_damage/emission_damage_id1.png"
#        alt="less aversion"
#        style="width:350px; height:auto;">
# </div>
#
# <!-- ——— Reproduction instructions ——— -->
# <div style="margin:0.8rem 0 0.2rem;">
#   To reproduce Figure 8 in the paper, run the shell scripts provided below.
# </div>
#
# ```bash
# bash ./conduction/Postdamage.sh "true" "false" "false" "false" "false"
# bash ./conduction/Postdamage_sub.sh "true" "false" "false" "false" "false"
# bash ./conduction/Predamage.sh "true" "false" "false" "false" "false"
# bash ./conduction/StocasticTrajectories_simulate.sh "true" "false"
# bash ./conduction/StocasticTrajectories_plot.sh "true" "false" "false"
# ```
#
# After the run finishes, you should have an output file named in a pattern similar to
# `path_investment_RD.png` and
# `emission_damage_id1.png`.
#
# Source scripts:
# * [**`Postdamage.sh`**](https://github.com/korito1416/two-capital-climate-change/blob/new_model_boundary/conduction/Postdamage.sh)
# * [**`Postdamage_sub.sh`**](https://github.com/korito1416/two-capital-climate-change/blob/new_model_boundary/conduction/Postdamage_sub.sh)
# * [**`Predamage.sh`**](https://github.com/korito1416/two-capital-climate-change/blob/new_model_boundary/conduction/Predamage.sh)
# * [**`StocasticTrajectories_simulate.sh`**](https://github.com/korito1416/two-capital-climate-change/blob/new_model_boundary/conduction/StocasticTrajectories_simulate.sh)
# * [**`StocasticTrajectories_plot.sh`**](https://github.com/korito1416/two-capital-climate-change/blob/new_model_boundary/conduction/StocasticTrajectories_plot.sh)
